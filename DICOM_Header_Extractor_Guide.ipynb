# %% [markdown]
# # DICOM Header Extractor
#
# This notebook provides a step-by-step guide to installing necessary libraries, cloning the DICOM Header Extractor repository, setting up the directory for DICOM files, and running the script to extract DICOM headers and de-identify specific tags.
#
#
# ## Steps:
# 1. **Install Pydicom library**: Install the required Pydicom library.
# 2. **Clone the repository**: Clone the DICOM Header Extractor repository from GitHub.
# 3. **Set the directory**: Configure the directory where your DICOM files are located.
# 4. **Run the script**: Execute the main script to extract and de-identify DICOM headers.

# %%
# 1. Install Pydicom library
# !pip install pydicom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.9 MB/s eta 0:00:00
# ...

# %%
# 2. Clone the repository
# !git clone https://github.com/dr-you-group/dicom-header-extractor.git
# !cd dicom-header-extractor
# Out:
# Cloning into 'dicom-header-extractor'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 45 (delta 11), reused 21 (delta 6), pack-reused 0
# Receiving objects: 100% (45/45), 13.56 KiB | 4.52 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# 3. Set the directory to search for DICOM files in config.txt
directory_to_search = '/path/to/your/DICOMdirectory'

with open('config.txt', 'w') as file:
    file.write(f'directory_to_search={directory_to_search}')

# %%
# 4. Run the script
# !python ./dicom-header-extractor/main.py
# Out:
# /usr/local/lib/python3.10/dist-packages/pydicom/valuerep.py:443: UserWarning: Invalid value for VR UI: '1.2.238.03.127.0.26702.20240520124026.1.2.2'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/pydicom/valuerep.py:443: UserWarning: Invalid value for VR UI: '1.2.238.03.127.0.26702.20240520124026'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/pydicom/valuerep.py:443: UserWarning: Invalid value for VR UI: '1.2.238.03.127.0.26702.20240520124026.1'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
